# %%
from util.dataset_transforms import ComposeImage, RandomResize
from torchvision import transforms
from torch.utils.data import DataLoader
from torchvision import datasets
import torch
import PIL
from matplotlib import pyplot as plt

# %%
img = PIL.Image.open("../resources/empty-viewport.png").convert("RGB")
# img = torch.zeros((3,50,64))

# %%
img.mode
# Out:
# 'RGB'

# %%
transf = [RandomResize((0.1,3.5)),ComposeImage(img), transforms.ToTensor()]
train_data = datasets.CIFAR10(root="../data", train=True, download=True, transform=transforms.Compose(transf))
train_loader = DataLoader(train_data, batch_size=512, shuffle=False)
# Out:
# Files already downloaded and verified

# %%
imgs = next(iter(train_loader))

# %%
plt.imshow(imgs[0][503].movedim(0,2))
